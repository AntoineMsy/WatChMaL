# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test = "out_00001.h5"

# %%
test[-8:-3]
# Out:
# '00001'

# %%
from IPython.display import display, HTML, Markdown
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_scroll { height: 44em; }</style>

# %%
import sys
import matplotlib
import matplotlib.pyplot as plt

# either add WatChMaL repository directory to PYTHONPATH environment variable or add it here
sys.path.append('/home/Antoine.m/WatChMaL')
sys.path.append('/home/Antoine.m')

# %%
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 28}
matplotlib.rc('font', **font)
matplotlib.rcParams['figure.figsize'] = (12, 8)
matplotlib.rcParams["figure.autolayout"] = True

# %%
import torch
import numpy as np
import pandas as pd
from watchmal.dataset.cnn_mpmt.cnn_mpmt_dataset import CNNmPMTDataset
from analysis.event_display.cnn_mpmt_event_display import CNNmPMTEventDisplay

# %%
dataset = CNNmPMTDataset(h5file='/home/Antoine.m/DataTools/out_test_km.h5',
                                    mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])

# %%
dataset_orig = CNNmPMTDataset(h5file='/home/pdeperio/machine_learning/data/IWCD_mPMT_Short/IWCD_mPMT_Short_emgp0_E0to1000MeV_digihits.h5',
                                    mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])

# %%
str(dataset_orig.h5_file["root_files"][8])[-10:-5]
# Out:
# 'ts_0.'

# %%
"home/amisery/projects/rpp-blairt2k/rakutsu/iwcd/mc/MassProNov2020/files/wcsim_root/NuMode/2p39/iwcd_p320ka_w750m_1e17pot_2p39_wcsim.00001.root"[-10:-5]
# Out:
# '00001'

# %%
event_display1 = CNNmPMTEventDisplay(h5file='/home/Antoine.m/DataTools/out_test.h5',
                                    mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])
event_display2 = CNNmPMTEventDisplay(h5file='/home/Antoine.m/DataTools/out_test_km.h5',
                                    mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-108829cbe2e2> in <module>
#       1 event_display1 = CNNmPMTEventDisplay(h5file='/home/Antoine.m/DataTools/out_test.h5',
# ----> 2                                     mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])
#       3 event_display2 = CNNmPMTEventDisplay(h5file='/home/Antoine.m/DataTools/out_test_km.h5',
#       4                                     mpmt_positions_file='/home/pdeperio/machine_learning/data/IWCDshort_mPMT_image_positions.npz', mode = ["charge"])
#
# ~/WatChMaL/watchmal/dataset/cnn_mpmt/cnn_mpmt_dataset.py in __init__(self, h5file, mpmt_positions_file, padding_type, transforms, mode, collapse_arrays, systematic_transform)
# ...

# %%
from matplotlib.colors import LogNorm
dict_label = {0: "no muon/gamma", 1 : "gamma", 2 : "muon", 3 : "pion"}
for i in range(len(event_display1)):
    event_id_to_plot = np.random.randint(0,len(event_display1))
    event_id_to_plot=i
    #event_id_to_plot = 307
    elem = event_display1[event_id_to_plot]
    event_display1.plot_event_2d(event_id_to_plot, color_label="Charge", style = "dark_background", title = "Original data, Event #%d"%(event_id_to_plot))
    event_display2.plot_event_2d(event_id_to_plot, color_label="Charge", style = "dark_background", title = "Ka Ming data, Event #%d"%(event_id_to_plot))

    # if elem["labels"] in [0,1,2]:
    #     event_display1.plot_event_2d(event_id_to_plot, color_label="Charge", style = "dark_background", title = "Original data, Event #%d"%(event_id_to_plot))
    # else : 
    #     print("issue on original dataset, event %d"%(event_id_to_plot))
    #     print(elem["labels"])  
    # elem = event_display2[event_id_to_plot]
    # if elem["labels"] in [0,1,2]:
    #     event_display2.plot_event_2d(event_id_to_plot, color_label="Charge", style = "dark_background", title = "Ka Ming data, Event #%d"%(event_id_to_plot))
    # else : 
    #     print("issue on ka ming dataset, event %d"%(event_id_to_plot))
    #     print(elem['labels'])
    # if np.abs(elem["cond_vec"][0]) > 500 and np.abs(elem["cond_vec"][0]) < 700 and elem["labels"] in [0,2]:
    #     event_display.plot_event_2d(event_id_to_plot, color_label="Charge", style = "dark_background", title = "Event #%d, %s type ring, energy %dMeV"%(event_id_to_plot,dict_label[elem["labels"]], elem["cond_vec"][0]))
    
    #ax = event_display.plot_processed_event_2d(event_id_to_plot, model, color_label="Charge", title=f"Event #{event_id_to_plot}", fig_size = 132)
    #ax = event_display.plot_diff_2d(event_id_to_plot, model, color_label="Charge", title=f"Event #{event_id_to_plot}", fig_size = 133)

    #ax = event_display.plot_generated_event_2d(event_id_to_plot, model, color_label="Charge", title=f"Event #{event_id_to_plot}",fig_size = 133)
# Out:
# /home/Antoine.m/WatChMaL/analysis/event_display/event_display.py:67: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize = fig_size)
